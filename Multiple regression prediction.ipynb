# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# %%
student_dataset = pd.read_csv('NEW RAW DATA.csv')

# %%
student_dataset.head()
# Out:
#    S/N   STUDENTS NAME  MATHS  ENGLISH  VERBAL  QUANT  BASIC SCIENCE  \
# 0  1.0     MICHAEL ENO   45.0     44.0    34.0   57.0           19.0
# 1  2.0     SAMUEL BALA   34.0     67.0    67.0   98.0           65.0
# 2  3.0      ISAH TANKO   65.0     89.0    87.0   76.0           43.0
# 3  4.0     ABDUL MAINA   98.0     90.0    54.0   54.0           56.0
# 4  5.0  FAVOUR GABRIEL   22.0     54.0    67.0   34.0           76.0
#
#    BUSINESS STUDIES  AGRIC  MARKETING  IRK/CRK  TOTAL  POSITION  INTELLIGENCE
# 0              45.0   45.0       55.0     22.0  366.0        15          3.05
# 1              67.0   67.0       55.0     34.0  554.0         7          4.62
# 2              65.0   45.0       55.0     56.0  581.0         5          4.84
# 3              43.0   67.0       55.0     78.0  595.0         3          4.96
# 4              23.0   98.0       67.0     54.0  495.0        11          4.13

# %%
student_dataset.dropna(inplace = True)

# %%
student_dataset
# Out:
#      S/N      STUDENTS NAME  MATHS  ENGLISH  VERBAL  QUANT  BASIC SCIENCE  \
# 0    1.0        MICHAEL ENO   45.0     44.0    34.0   57.0           19.0
# 1    2.0        SAMUEL BALA   34.0     67.0    67.0   98.0           65.0
# 2    3.0         ISAH TANKO   65.0     89.0    87.0   76.0           43.0
# 3    4.0        ABDUL MAINA   98.0     90.0    54.0   54.0           56.0
# 4    5.0     FAVOUR GABRIEL   22.0     54.0    67.0   34.0           76.0
# 5    6.0          ISAH UMMI   45.0     55.0    89.0   56.0           54.0
# 6    7.0       FARIDA SHEHU   98.0     67.0    76.0   78.0           32.0
# 7    8.0        ADAMU ADAMU   65.0     87.0    54.0   98.0           56.0
# 8    9.0      JULIANA AJAYI   54.0     65.0    32.0   73.0           78.0
# 9   10.0     JOSEPH FARINTO   76.0     43.0    45.0   26.0           65.0
# 10  11.0     JERIMIAH ALANI   78.0     23.0    67.0   75.0           43.0
# 11  12.0   ABDULWASIU JAFAR   67.0     56.0    89.0   43.0           76.0
# ...

# %%
student_dataset.shape
# Out:
# (15, 14)

# %%
student_dataset.dtypes
# Out:
# S/N                 float64
# STUDENTS NAME        object
# MATHS               float64
# ENGLISH             float64
# VERBAL              float64
# QUANT               float64
# BASIC SCIENCE       float64
# BUSINESS STUDIES    float64
# AGRIC               float64
# MARKETING           float64
# IRK/CRK             float64
# TOTAL               float64
# POSITION              int64
# INTELLIGENCE        float64
# dtype: object

# %%
student_dataset.columns
# Out:
# Index(['S/N', 'STUDENTS NAME', 'MATHS', 'ENGLISH', 'VERBAL', 'QUANT',
#        'BASIC SCIENCE', 'BUSINESS STUDIES', 'AGRIC', 'MARKETING', 'IRK/CRK',
#        'TOTAL', 'POSITION', 'INTELLIGENCE'],
#       dtype='object')

# %%
student_dataset.describe()
# Out:
#              S/N      MATHS    ENGLISH     VERBAL      QUANT  BASIC SCIENCE  \
# count  15.000000  15.000000  15.000000  15.000000  15.000000      15.000000
# mean    8.000000  60.466667  60.133333  62.533333  62.400000      57.400000
# std     4.472136  21.526949  20.106384  18.844729  23.126361      18.511772
# min     1.000000  22.000000  23.000000  32.000000  25.000000      19.000000
# 25%     4.500000  45.000000  49.000000  49.500000  48.500000      48.500000
# 50%     8.000000  62.000000  56.000000  67.000000  67.000000      56.000000
# 75%    11.500000  71.500000  71.500000  76.000000  76.000000      70.500000
# max    15.000000  98.000000  90.000000  89.000000  98.000000      89.000000
#
#        BUSINESS STUDIES      AGRIC  MARKETING    IRK/CRK       TOTAL  \
# count         15.000000  15.000000  15.000000  15.000000   15.000000
# mean          56.733333  58.133333  62.333333  53.000000  533.133333
# std           16.619552  19.297915  16.020820  25.798671   74.011453
# ...

# %%
student_dataset.isnull().sum()
# Out:
# S/N                 0
# STUDENTS NAME       0
# MATHS               0
# ENGLISH             0
# VERBAL              0
# QUANT               0
# BASIC SCIENCE       0
# BUSINESS STUDIES    0
# AGRIC               0
# MARKETING           0
# IRK/CRK             0
# TOTAL               0
# POSITION            0
# INTELLIGENCE        0
# dtype: int64

# %% [markdown]
# X_FEATURE

# %%
x_feature = ['MATHS','ENGLISH','VERBAL','QUANT','BASIC SCIENCE','BUSINESS STUDIES','AGRIC','MARKETING', 'IRK/CRK']

# %%
x_feature2 = student_dataset[x_feature]

# %%
y_target=['INTELLIGENCE']

# %%
y_target2=student_dataset[y_target]

# %% [markdown]
# VIEW DATASHAPE

# %%
print(x_feature2.shape)
# Out:
# (15, 9)

# %%
print(y_target2.shape)
# Out:
# (15, 1)

# %% [markdown]
# MULTIPLE LINEAR REGRESSION

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_feature2,y_target2,test_size=0.3, random_state=0)

# %% [markdown]
# IMPORT THE TRAINING AND TESTING DATASETS

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()

# %%
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(x_test)

# %%
 pd.DataFrame({'Actual': [y_test], 'Predicted':[y_pred]})
# Out:
#                                               Actual  \
# 0      INTELLIGENCE
# 1           4.62
# 6           ...
#
#                                            Predicted
# 0  [[4.632891075599749], [4.838982002264952], [5....
